# %%
import act 
import xarray as xr 
import numpy as np
import pandas as pd

import dask

# %%
username = 'nalex'
token = '73a87dffb0bbdfcd'

# Set the datastream and start/enddates
datastream = 'anx30ecorM1.b1'
startdate = '2019-12-01'
enddate = '2020-06-15'

# Use ACT to easily download the data.  Watch for the data citation!  Show some support
# for ARM's instrument experts and cite their data if you use it in a publication
result = act.discovery.download_arm_data(username, token, datastream, startdate, enddate)

# %%
import glob
anx_files = glob.glob('anx30ecorM1.b1/*')

nsa_files = glob.glob('nsa30qcecorE10.s1/*')


ds_nsa = xr.open_mfdataset(nsa_files)

ds_anx = xr.open_mfdataset(anx_files)
# Out:
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/xarray/core/concat.py:546: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   common_dims = tuple(pd.unique([d for v in vars for d in v.dims]))
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/xarray/core/concat.py:546: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   common_dims = tuple(pd.unique([d for v in vars for d in v.dims]))
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/xarray/core/concat.py:546: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   common_dims = tuple(pd.unique([d for v in vars for d in v.dims]))
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/xarray/core/concat.py:546: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   common_dims = tuple(pd.unique([d for v in vars for d in v.dims]))

# %% [markdown]
# # ANX site ECOR data
# COMBLE period

# %%
anx_weak_events = ['2020-01-25T20:00:30.000000000''2020-01-25T22:00:30.000000000'
 '2020-01-26T00:00:30.000000000''2020-01-26T02:00:30.000000000'
 '2020-01-26T04:00:30.000000000' '2020-01-26T06:00:30.000000000'
 '2020-02-04T16:00:30.000000000' '2020-02-04T18:00:30.000000000'
 '2020-02-04T20:00:30.000000000' '2020-02-05T08:00:30.000000000'
 '2020-02-05T14:00:30.000000000' '2020-02-05T16:00:30.000000000'
 '2020-02-05T18:00:30.000000000' '2020-02-05T20:00:30.000000000'
 '2020-02-29T22:00:30.000000000' '2020-03-01T00:00:30.000000000'
 '2020-03-01T02:00:30.000000000' '2020-03-01T04:00:30.000000000'
 '2020-03-01T06:00:30.000000000' '2020-03-01T08:00:30.000000000'
 '2020-03-01T10:00:30.000000000' '2020-03-01T12:00:30.000000000'
 '2020-03-12T22:00:30.000000000' '2020-03-13T00:00:30.000000000'
 '2020-03-13T02:00:30.000000000' '2020-03-13T16:00:30.000000000'
 '2020-03-13T18:00:30.000000000' '2020-03-13T20:00:30.000000000'
 '2020-03-13T22:00:30.000000000' '2020-03-14T00:00:30.000000000'
 '2020-03-14T02:00:30.000000000' '2020-03-14T04:00:30.000000000'
 '2020-03-14T06:00:30.000000000' '2020-03-14T08:00:30.000000000'
 '2020-03-19T04:00:30.000000000' '2020-03-19T06:00:30.000000000'
 '2020-03-19T08:00:30.000000000' '2020-03-19T10:00:30.000000000'
 '2020-03-19T12:00:30.000000000' '2020-03-19T14:00:30.000000000'
 '2020-03-19T16:00:30.000000000' '2020-03-19T18:00:30.000000000'
 '2020-03-19T20:00:30.000000000' '2020-03-20T02:00:30.000000000'
 '2020-03-20T04:00:30.000000000' '2020-03-20T06:00:30.000000000'
 '2020-03-20T08:00:30.000000000' '2020-03-20T16:00:30.000000000'
 '2020-03-20T18:00:30.000000000' '2020-03-20T20:00:30.000000000'
 '2020-03-20T22:00:30.000000000' '2020-03-21T00:00:30.000000000'
 '2020-03-21T02:00:30.000000000' '2020-03-21T04:00:30.000000000'
 '2020-03-28T06:00:30.000000000' '2020-03-28T08:00:30.000000000'
 '2020-03-28T10:00:30.000000000' '2020-03-28T12:00:30.000000000'
 '2020-03-28T14:00:30.000000000' '2020-03-28T16:00:30.000000000'
 '2020-03-28T18:00:30.000000000' '2020-03-28T20:00:30.000000000'
 '2020-03-29T18:00:30.000000000' '2020-03-29T20:00:30.000000000'
 '2020-03-29T22:00:30.000000000' '2020-03-30T00:00:30.000000000'
 '2020-03-30T02:00:30.000000000' '2020-03-30T04:00:30.000000000'
 '2020-03-30T06:00:30.000000000' '2020-03-30T08:00:30.000000000']

strong_events = ['2020-02-05T10:00:30.000000000' '2020-02-05T12:00:30.000000000'
 '2020-03-13T04:00:30.000000000' '2020-03-13T06:00:30.000000000'
 '2020-03-13T08:00:30.000000000' '2020-03-13T10:00:30.000000000'
 '2020-03-13T12:00:30.000000000' '2020-03-13T14:00:30.000000000'
 '2020-03-28T22:00:30.000000000' '2020-03-29T00:00:30.000000000'
 '2020-03-29T02:00:30.000000000' '2020-03-29T04:00:30.000000000'
 '2020-03-29T06:00:30.000000000' '2020-03-29T08:00:30.000000000'
 '2020-03-29T10:00:30.000000000' '2020-03-29T12:00:30.000000000'
 '2020-03-29T14:00:30.000000000' '2020-03-29T16:00:30.000000000']

strong_events = [x for x in strong_events[0].split('.000000000')]

strong_events = pd.to_datetime(strong_events)


anx_weak_events = [x for x in anx_weak_events[0].split('.000000000')]

anx_weak_events = pd.to_datetime(anx_weak_events)

# %%
import matplotlib.dates as mdates


def plot_weak_strong(ds,weak,strong,label):
    fig,ax = plt.subplots(1,1,figsize=(10,5))


    for event in weak:
        ax.axvline(event,color='g',linestyle='--')

    for event in strong:
        ax.axvline(event,color='r',linestyle='--')
    ds.plot(ax=ax,label=f'{label} Heat Flux (W/m^2) - 2020')

    ax.set_title(f'{label} Heat Flux and Strong/Weak Events - ANX')

    ax.set_ylabel(f'{label} Heat Flux (W/m^2) - 2020')

    ax.set_xlabel('Time')
    ax.set_ylim(-1e13,1e13)

    ax.xaxis.set_major_locator(mdates.WeekdayLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
    ax.set_xlim('2020-01-12','2020-06-01')
    
    ax.grid()
    ax.legend()

plot_weak_strong(ds_anx['h'],anx_weak_events,strong_events,
                 label='Sensible')

# %%
plot_weak_strong(ds_anx['lv_e'],anx_weak_events,strong_events,
                 label='Latent')

# %%
weak_data = ds_anx['h'].sel(time=anx_weak_events,
                            method='nearest').shift(time=4)


strong_data = ds_anx['h'].sel(time=strong_events,
                              
                                method='nearest').shift(time=4)




diurnal_weak = weak_data.groupby('time.hour').mean(dim='time')


diurnal_strong = strong_data.groupby('time.hour').mean(dim='time')




fig,ax = plt.subplots(1,2,figsize=(10,5))

diurnal_weak.plot(ax=ax[0])

ax[0].set_title('Weak Event Diurnal Cycle')

ax[0].set_ylabel('Latent Heat Flux (W/m^2)')

ax[0].set_xlabel('Hour of Day')


diurnal_strong.plot(ax=ax[1])

ax[1].set_title('Strong Event Diurnal Cycle')

ax[1].set_ylabel('Latent Heat Flux (W/m^2)')

for ii in range(2):
    ax[ii].grid()
    ax[ii].set_ylim(-0,300)
    ax[ii].set_xlim(0,23)

# %%
import seaborn as sbs 


fig,ax = plt.subplots(1,1,figsize=(10,5))

#weak_data = weak_data.to_dataframe()

#strong_data = strong_data.to_dataframe()

sbs.kdeplot(weak_data,label='Weak Events',ax=ax)

sbs.kdeplot(strong_data,label='Strong Events',ax=ax)

ax.legend()

# %%
weak_data.tp_data
# Out:
# <xarray.DataArray 'h' (time: 71)>
# dask.array<rechunk-merge, shape=(71,), dtype=float32, chunksize=(9,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2020-01-25T20:00:00 ... 2020-06-02T08:30:00
# Attributes:
#     long_name:   Sensible heat flux
#     units:       W/m^2
#     valid_min:   -300.0
#     valid_max:   1500.0
#     resolution:  0.1

# %%
import plotly.figure_factory as ff
import numpy as np

# Assuming you have another dataset named 'strong_data'
group_labels = ['weak_events', 'strong_events'] # names of the datasets

fig = ff.create_distplot([weak_data.dropna(dim='time').values, strong_data.dropna(dim='time').values], group_labels, bin_size=0.5,
                         show_hist=False)

# add xlabel

fig.update_layout(
    xaxis_title_text='Latent Heat Flux (W/m^2)',
    title='Latent Heat Flux Distribution for Strong and Weak Events',
    xaxis = dict(
        tickmode = 'linear',
        tick0 = 0,
        dtick = 50
    ),
    yaxis = dict(
        title = 'Density'
    )

)

fig.show()

# %%
username = 'nalex'
token = '73a87dffb0bbdfcd'

# Set the datastream and start/enddates
datastream = 'anxdlprofwstats4newsS2.c1'
startdate = '2019-12-01'
enddate = '2020-06-15'

# Use ACT to easily download the data.  Watch for the data citation!  Show some support
# for ARM's instrument experts and cite their data if you use it in a publication
result = act.discovery.download_arm_data(username, token, datastream, startdate, enddate)
# Out:
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191205.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200114.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200115.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200116.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200117.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200118.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200120.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200119.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200122.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200125.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200126.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200128.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200127.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200130.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200201.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200202.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200225.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200302.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200305.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200319.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200322.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200330.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200402.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200407.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200415.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200418.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200425.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200426.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200428.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191229.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200123.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200124.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200211.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200213.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200212.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200215.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200218.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200221.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200220.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200222.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200223.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200224.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200227.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200229.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200226.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200301.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200303.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200304.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200309.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200308.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200310.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200312.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200314.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200318.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200327.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191209.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191210.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191211.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191212.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200102.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200103.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200105.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200104.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200106.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200107.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200109.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200108.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200219.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200306.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200307.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200311.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200313.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200315.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200316.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200317.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200403.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200405.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200408.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200410.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200409.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200411.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200412.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200413.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200414.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200416.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200417.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200421.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200422.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200429.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200502.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200503.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200504.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200509.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200510.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191202.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191203.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191201.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191206.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191208.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191207.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191220.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191222.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191224.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191223.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200129.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200131.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200203.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200205.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200206.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200207.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200208.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200214.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191204.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191217.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191218.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191213.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191214.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191215.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191216.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191219.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191221.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191225.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191227.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191226.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191228.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191230.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200101.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20191231.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200110.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200113.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200111.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200112.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200121.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200209.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200210.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200506.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200505.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200507.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200508.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200512.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200514.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200513.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200515.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200517.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200519.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200518.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200520.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200217.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200216.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200228.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200320.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200321.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200323.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200324.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200325.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200326.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200401.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200404.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200406.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200430.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200501.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200528.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200529.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200531.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200328.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200329.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200331.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200419.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200420.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200423.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200424.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200427.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200511.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200516.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200526.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200527.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200530.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200601.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200521.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200522.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200523.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200525.000000.nc
# [DOWNLOADING] anxdlprofwstats4newsS2.c1.20200524.000000.nc
#
# If you use these data to prepare a publication, please cite:
#
# Shippert, T., Newsom, R., Riihimaki, L., & Zhang, D. Doppler Lidar Wind
# Statistics Profiles (DLPROFWSTATS4NEWS). Atmospheric Radiation Measurement (ARM)
# User Facility. https://doi.org/10.5439/1178583

# %%
# Out:
#   Cell In[271], line 8
#     fig.add_trace(go.Scatter(x=weak_data['time'],y=weak_data['lv_e'],
#                                                                      ^
# SyntaxError: incomplete input

# %% [markdown]
# ## COMBLE interposond ANX
